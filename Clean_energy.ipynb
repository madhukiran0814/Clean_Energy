# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
data=pd.read_csv("https://github.com/jojo62000/Smarter_Decisions/raw/master/Chapter%206/Data/Final_SolarData.csv")

# %%
data
# Out:
#        location            date_time  solarvoltage  solarcurrent  solarenergy  \
# 0          Peru  2015-12-02 00:00:27           0.0          0.00          0.0
# 1          Peru  2015-12-02 00:01:40           0.0          0.00          0.0
# 2          Peru  2015-12-02 00:02:52           0.0          0.00          0.0
# 3          Peru  2015-12-02 00:04:05           0.0          0.00          0.0
# 4          Peru  2015-12-02 00:05:18           0.0          0.00          0.0
# ...         ...                  ...           ...           ...          ...
# 119291     Peru  2016-03-14 22:22:02           0.0          1.11          0.0
# 119292     Peru  2016-03-14 22:23:14           0.0          1.11          0.0
# 119293     Peru  2016-03-14 22:24:27           0.0          1.23          0.0
# 119294     Peru  2016-03-14 22:25:40           0.0          1.17          0.0
# 119295     Peru  2016-03-14 22:26:52           0.0          1.17          0.0
#
# ...

# %%
data.columns
# Out:
# Index(['location', 'date_time', 'solarvoltage', 'solarcurrent', 'solarenergy',
#        'solarpower', 'batteryvoltage', 'batterycurrent', 'batterypower',
#        'load_energy1', 'load_power1', 'load_current1', 'load_voltage1',
#        'load_energy2', 'load_power2', 'load_current2', 'load_voltage2',
#        'inverter_input_power', 'inverter_output_power',
#        'inverter_input_energy', 'inverter_output_energy', 'irradiance',
#        'temperature'],
#       dtype='object')

# %%
data.describe
# Out:
# <bound method NDFrame.describe of        location            date_time  solarvoltage  solarcurrent  solarenergy  \
# 0          Peru  2015-12-02 00:00:27           0.0          0.00          0.0
# 1          Peru  2015-12-02 00:01:40           0.0          0.00          0.0
# 2          Peru  2015-12-02 00:02:52           0.0          0.00          0.0
# 3          Peru  2015-12-02 00:04:05           0.0          0.00          0.0
# 4          Peru  2015-12-02 00:05:18           0.0          0.00          0.0
# ...         ...                  ...           ...           ...          ...
# 119291     Peru  2016-03-14 22:22:02           0.0          1.11          0.0
# 119292     Peru  2016-03-14 22:23:14           0.0          1.11          0.0
# 119293     Peru  2016-03-14 22:24:27           0.0          1.23          0.0
# 119294     Peru  2016-03-14 22:25:40           0.0          1.17          0.0
# 119295     Peru  2016-03-14 22:26:52           0.0          1.17          0.0
#
# ...

# %%
data["solarenergy"].value_counts()
# Out:
# 0.00    76300
# 0.02     7137
# 0.01     6192
# 0.02     5040
# 0.03     2956
#         ...
# 0.18        1
# 0.38        1
# 0.25        1
# 0.71        1
# 0.12        1
# Name: solarenergy, Length: 100, dtype: int64

# %%
plt.scatter(data["solarvoltage"],data["batteryvoltage"])

# %%
for i in range(2,10):
    for j in range(2,10):
        plt.scatter(data.iloc[:,i],data.iloc[:,j],label=j)

# %%
from sklearn.pipeline import make_pipeline
from sklearn.preprocessing import Normalizer
from sklearn.preprocessing import MinMaxScaler  
from sklearn.compose import make_column_transformer 
from sklearn.metrics import r2_score

# %%
r2_test = r2_score(data["solarvoltage"],data["batteryvoltage"])
print('R-Square: ', round(r2_test, 2))
# Out:
# R-Square:  -0.01

# %%
actual = (data["solarvoltage"].sum()/4/1000).round(2)  
predicted = (data["batteryvoltage"].sum()/4/1000).round(2) 
print('Actual annual Solar Energy Generated by Southland Solar Station: {} MWh'.format(actual))
print('Predicted annual Solar Energy Generated by Southland Solar Stations: {} MWh'.format(predicted))
# Out:
# Actual annual Solar Energy Generated by Southland Solar Station: 2432.19 MWh
# Predicted annual Solar Energy Generated by Southland Solar Stations: 2943.36 MWh

# %%
#No Nulls in Date

# %%
data["date_time"].isnull().value_counts
# Out:
# <bound method IndexOpsMixin.value_counts of 0         False
# 1         False
# 2         False
# 3         False
# 4         False
#           ...
# 119291    False
# 119292    False
# 119293    False
# 119294    False
# 119295    False
# Name: date_time, Length: 119296, dtype: bool>

# %%
data.isnull().value_counts
# Out:
# <bound method DataFrame.value_counts of         location  date_time  solarvoltage  solarcurrent  solarenergy  \
# 0          False      False         False         False        False
# 1          False      False         False         False        False
# 2          False      False         False         False        False
# 3          False      False         False         False        False
# 4          False      False         False         False        False
# ...          ...        ...           ...           ...          ...
# 119291     False      False         False         False        False
# 119292     False      False         False         False        False
# 119293     False      False         False         False        False
# 119294     False      False         False         False        False
# 119295     False      False         False         False        False
#
#         solarpower  batteryvoltage  batterycurrent  batterypower  \
# ...

# %%
#Filling NULL values with Zeros

# %%
data.fillna(0)
# Out:
#        location            date_time  solarvoltage  solarcurrent  solarenergy  \
# 0          Peru  2015-12-02 00:00:27           0.0          0.00          0.0
# 1          Peru  2015-12-02 00:01:40           0.0          0.00          0.0
# 2          Peru  2015-12-02 00:02:52           0.0          0.00          0.0
# 3          Peru  2015-12-02 00:04:05           0.0          0.00          0.0
# 4          Peru  2015-12-02 00:05:18           0.0          0.00          0.0
# ...         ...                  ...           ...           ...          ...
# 119291     Peru  2016-03-14 22:22:02           0.0          1.11          0.0
# 119292     Peru  2016-03-14 22:23:14           0.0          1.11          0.0
# 119293     Peru  2016-03-14 22:24:27           0.0          1.23          0.0
# 119294     Peru  2016-03-14 22:25:40           0.0          1.17          0.0
# 119295     Peru  2016-03-14 22:26:52           0.0          1.17          0.0
#
# ...
